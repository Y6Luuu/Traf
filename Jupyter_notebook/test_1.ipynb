# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\Yuyan.Lu\AppData\Local\Programs\Microsoft VS Code\Jupyter_notebook\data_source\FFCA_1104.xlsx', engine='openpyxl')

# %%
df
# Out:
#       Purchase Assignment ID  Blend Type  Inventory ID       Commodity  \
# 0                668920.9.14  PaperBlend        849520  Copper Blister
# 1                668920.8.19           -        834732  Copper Blister
# 2                649921.11.6           -        619548  Copper Blister
# 3                659833.19.1  PaperBlend        782604     LBMA Silver
# 4                 673504.1.6           -        785474     LBMA Silver
# ...                      ...         ...           ...             ...
# 60267          667273.10.156           -        853007            Zinc
# 60268            681425.1.42           -        847970          Copper
# 60269            681425.1.42           -        847970          Copper
# 60270           673424.3.163           -        851977       Aluminium
# 60271           673424.3.163           -        851977       Aluminium
#
#                                 Counterparty of Purchase       QTY  \
# ...

# %%
g1 = df.groupby(["Sales Assignment ID"], as_index=False)

# %%
# Out:
# [('646299.10.1',
#     Sales Assignment ID Purchase Assignment ID Sales Valuation Currency  \
#   0         646299.10.1            652360.12.1                      USD
#
#     Financing Bank facility MMI Amount MMI Currency  Purchase Settled Amount  \
#   0                       -          -            -              -11614680.0
#
#      Sales Settled Amount
#   0            16412130.0  ),
#  ('646299.7.1',
#     Sales Assignment ID Purchase Assignment ID Sales Valuation Currency  \
#   1          646299.7.1             652360.6.1                      USD
#
#     Financing Bank facility MMI Amount MMI Currency  Purchase Settled Amount  \
#   1                       -          -            -               -9699480.0
#
#      Sales Settled Amount
#   1            17084340.0  ),
#  ('646299.8.1',
#     Sales Assignment ID Purchase Assignment ID Sales Valuation Currency  \
#   2          646299.8.1            652360.10.1                      USD
#
# ...

# %%
g1.to_excel(r'K:\FINANCE\Concs\_ Yuyan\Macro\python\g1.xlsx', index=False)
